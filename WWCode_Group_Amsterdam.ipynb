# %% [markdown]
# # AirBnB Data: Amsterdam

# %% [markdown]
# Script for unzipping gz files.

# %% [markdown]
# import gzip
# with gzip.open('my_file.csv.gz', 'rt', newline='') as csv_file:
#     csv_data = csv_file.read()
#     with open('my_file.csv', 'wt') as out_file:
#          out_file.write(csv_data)
# #💡 Note: Depending on the .csv.gz file’s encoding, you may want to pass encoding='utf-8', 'latin-1', utf-16', or your specific file encoding into gzip.open() to prevent any encoding/decoding errors.

# %% [markdown]
# Import necesary package for data exploration

# %%
import pandas as pd

# %% [markdown]
# Read csv file and view it's contents.

# %%
amsterdam = pd.read_csv('listings.csv')
amsterdam
# Out:
#             id                            listing_url       scrape_id  \
# 0         2818      https://www.airbnb.com/rooms/2818  20220907151523
# 1        20168     https://www.airbnb.com/rooms/20168  20220907151523
# 2        27886     https://www.airbnb.com/rooms/27886  20220907151523
# 3        28871     https://www.airbnb.com/rooms/28871  20220907151523
# 4        29051     https://www.airbnb.com/rooms/29051  20220907151523
# ...        ...                                    ...             ...
# 6888  12690380  https://www.airbnb.com/rooms/12690380  20220907151523
# 6889  15005354  https://www.airbnb.com/rooms/15005354  20220907151523
# 6890  15171981  https://www.airbnb.com/rooms/15171981  20220907151523
# 6891  17567812  https://www.airbnb.com/rooms/17567812  20220907151523
# 6892  20084434  https://www.airbnb.com/rooms/20084434  20220907151523
#
#      last_scraped           source  \
# 0      2022-09-07      city scrape
# 1      2022-09-07  previous scrape
# ...

# %%
amsterdam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6893 entries, 0 to 6892
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            6893 non-null   int64
#  1   listing_url                                   6893 non-null   object
#  2   scrape_id                                     6893 non-null   int64
#  3   last_scraped                                  6893 non-null   object
#  4   source                                        6893 non-null   object
#  5   name                                          6893 non-null   object
#  6   description                                   6877 non-null   object
#  7   neighborhood_overview                         4628 non-null   object
#  8   picture_url                                   6893 non-null   object
# ...

# %% [markdown]
# Load further details into new dataframe

# %%
listings = pd.read_csv('listings_details.csv')
listings
# Out:
#               id                                               name   host_id  \
# 0         2818.0           Quiet Garden View Room & Super Fast WiFi      3159
# 1        20168.0       Studio with private bathroom in the centre 1     59484
# 2        27886.0  Romantic, stylish B&B houseboat in canal district     97647
# 3        28871.0                            Comfortable double room    124245
# 4        29051.0                            Comfortable single room    124245
# ...          ...                                                ...       ...
# 6888  12690380.0  Amsterdam, light big house 15 min from citycenter  15032494
# 6889  15005354.0                 Perfect family home near Amsterdam  46437958
# 6890  15171981.0  Child friendly house near Amsterdam - free par...  96286859
# 6891  17567812.0  Modern, spacious family home, 5 bedrooms-Amste...  55072916
# 6892  20084434.0  Single-family house (15m cycling center Amster...  29435851
#
# ...

# %% [markdown]
# View columns

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6893 entries, 0 to 6892
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              6893 non-null   float64
#  1   name                            6893 non-null   object
#  2   host_id                         6893 non-null   int64
#  3   host_name                       6893 non-null   object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   6893 non-null   object
#  6   latitude                        6893 non-null   float64
#  7   longitude                       6893 non-null   float64
#  8   room_type                       6893 non-null   object
#  9   price                           6893 non-null   int64
#  10  minimum_nights                  6893 non-null   int64
#  11  number_of_reviews               6893 non-null   int64
# ...

# %% [markdown]
# Merge Listings and Listing Details files on their common ID for one large dataframe.

# %%
Amsterdam = pd.merge(amsterdam, listings, on="id", how= "left")
Amsterdam
# Out:
#             id                            listing_url       scrape_id  \
# 0         2818      https://www.airbnb.com/rooms/2818  20220907151523
# 1        20168     https://www.airbnb.com/rooms/20168  20220907151523
# 2        27886     https://www.airbnb.com/rooms/27886  20220907151523
# 3        28871     https://www.airbnb.com/rooms/28871  20220907151523
# 4        29051     https://www.airbnb.com/rooms/29051  20220907151523
# ...        ...                                    ...             ...
# 6888  12690380  https://www.airbnb.com/rooms/12690380  20220907151523
# 6889  15005354  https://www.airbnb.com/rooms/15005354  20220907151523
# 6890  15171981  https://www.airbnb.com/rooms/15171981  20220907151523
# 6891  17567812  https://www.airbnb.com/rooms/17567812  20220907151523
# 6892  20084434  https://www.airbnb.com/rooms/20084434  20220907151523
#
#      last_scraped           source  \
# 0      2022-09-07      city scrape
# 1      2022-09-07  previous scrape
# ...

# %% [markdown]
# Handle each missing value on case by case basis with removeing features, rows or imputing null value with new value.

# %% [markdown]
# Check for duplicates

# %%
Amsterdam.id.nunique()
# Out:
# 6893

# %%
# Check number of duplicates while ignoring the index feature
n_duplicates = Amsterdam.drop(labels=["id"], axis=1).duplicated().sum()
print(f"You seem to have {n_duplicates} duplicates in your database.")
# Out:
# You seem to have 0 duplicates in your database.

# %% [markdown]
# View distribution of datatypes of features

# %%
Amsterdam.dtypes.value_counts()
# Out:
# object     41
# float64    32
# int64      19
# dtype: int64

# %% [markdown]
# Pull out numerical features to take a look

# %%
numericals = Amsterdam.select_dtypes(exclude=["object"])
numericals
# Out:
#             id       scrape_id  host_id_x  host_listings_count  \
# 0         2818  20220907151523       3159                    1
# 1        20168  20220907151523      59484                    5
# 2        27886  20220907151523      97647                    1
# 3        28871  20220907151523     124245                    2
# 4        29051  20220907151523     124245                    2
# ...        ...             ...        ...                  ...
# 6888  12690380  20220907151523   15032494                    1
# 6889  15005354  20220907151523   46437958                    1
# 6890  15171981  20220907151523   96286859                    1
# 6891  17567812  20220907151523   55072916                    1
# 6892  20084434  20220907151523   29435851                    1
#
#       host_total_listings_count  neighbourhood_group_cleansed  latitude_x  \
# 0                             1                           NaN    52.36435
# ...
